# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform (-180, 180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]    
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | novyy urgal
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | clyde river
# Processing Record 5 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | vila
# Processing Record 10 of Set 1 | selikhino
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | karangasem
# Processing Record 13 of Set 1 | ponta do sol
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | rach gia
# Processing Record 16 of Set 1 | kaitangata
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | kolaras
# Processing Record 19 of Set 1 | webuye
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | ussel
# Processing Record 24 of Set 1 | wanning
# Processing Record 25 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 1 | abomsa
# Processing Record 27 of Set 1 | meulaboh
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | lasa
# Processing Record 31 of Set 1 | kushiro
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | san quintin
# Processing Record 34 of Set 1 | hamilton
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | laguna
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | hervey bay
# Processing Record 40 of Set 1 | bockenem
# Processing Record 41 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | urumqi
# Processing Record 44 of Set 1 | akyab
# Processing Record 45 of Set 1 | sakaiminato
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | svetlyy
# Processing Record 1 of Set 2 | vila franca do campo
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | kontagora
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | quesnel
# Processing Record 11 of Set 2 | zhicheng
# Processing Record 12 of Set 2 | avera
# Processing Record 13 of Set 2 | sangar
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | uarini
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | jalu
# Processing Record 21 of Set 2 | lucapa
# Processing Record 22 of Set 2 | upernavik
# Processing Record 23 of Set 2 | la ronge
# Processing Record 24 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 2 | kirakira
# Processing Record 26 of Set 2 | bud
# Processing Record 27 of Set 2 | merrill
# Processing Record 28 of Set 2 | korla
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | kibuye
# Processing Record 31 of Set 2 | outjo
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | kiama
# Processing Record 34 of Set 2 | samarai
# Processing Record 35 of Set 2 | aklavik
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | birao
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | walvis bay
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | lithakia
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | skibbereen
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | gat
# Processing Record 8 of Set 3 | atar
# Processing Record 9 of Set 3 | muisne
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | ila
# Processing Record 12 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 3 | barcelos
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | san vicente
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | okoneshnikovo
# Processing Record 20 of Set 3 | san carlos
# Processing Record 21 of Set 3 | bulungu
# Processing Record 22 of Set 3 | kimbe
# Processing Record 23 of Set 3 | high level
# Processing Record 24 of Set 3 | ketchikan
# Processing Record 25 of Set 3 | seymchan
# Processing Record 26 of Set 3 | buala
# Processing Record 27 of Set 3 | cockburn town
# Processing Record 28 of Set 3 | rafai
# Processing Record 29 of Set 3 | bilma
# Processing Record 30 of Set 3 | bethel
# Processing Record 31 of Set 3 | gimli
# Processing Record 32 of Set 3 | tateyama
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | pecos
# Processing Record 36 of Set 3 | natal
# Processing Record 37 of Set 3 | thinadhoo
# Processing Record 38 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | brigantine
# Processing Record 40 of Set 3 | alyangula
# Processing Record 41 of Set 3 | progreso
# Processing Record 42 of Set 3 | sal rei
# Processing Record 43 of Set 3 | tual
# Processing Record 44 of Set 3 | mustafakemalpasa
# Processing Record 45 of Set 3 | tadine
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | ust-omchug
# Processing Record 48 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 3 | champerico
# Processing Record 50 of Set 3 | jiangkou
# Processing Record 1 of Set 4 | tazovskiy
# Processing Record 2 of Set 4 | northam
# Processing Record 3 of Set 4 | thompson
# Processing Record 4 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 4 | atuona
# Processing Record 6 of Set 4 | san jose
# Processing Record 7 of Set 4 | nenjiang
# Processing Record 8 of Set 4 | mayumba
# Processing Record 9 of Set 4 | ewa beach
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | batagay
# Processing Record 12 of Set 4 | tasiilaq
# Processing Record 13 of Set 4 | te anau
# Processing Record 14 of Set 4 | faya
# Processing Record 15 of Set 4 | broome
# Processing Record 16 of Set 4 | along
# Processing Record 17 of Set 4 | monrovia
# Processing Record 18 of Set 4 | arona
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | waipawa
# Processing Record 21 of Set 4 | katsuura
# Processing Record 22 of Set 4 | skeldon
# Processing Record 23 of Set 4 | bathsheba
# Processing Record 24 of Set 4 | lomovka
# Processing Record 25 of Set 4 | cartagena del chaira
# Processing Record 26 of Set 4 | eyl
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | leningradskiy
# Processing Record 29 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 4 | union
# Processing Record 31 of Set 4 | morondava
# Processing Record 32 of Set 4 | sivas
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | verkhniy uslon
# Processing Record 35 of Set 4 | mukono
# Processing Record 36 of Set 4 | acajutla
# Processing Record 37 of Set 4 | camacha
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | jasper
# Processing Record 40 of Set 4 | fort nelson
# Processing Record 41 of Set 4 | robertson
# Processing Record 42 of Set 4 | aksu
# Processing Record 43 of Set 4 | batagay-alyta
# Processing Record 44 of Set 4 | hambantota
# Processing Record 45 of Set 4 | chamrajnagar
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | saint-philippe
# Processing Record 48 of Set 4 | cayenne
# Processing Record 49 of Set 4 | beloha
# Processing Record 50 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 5 | muncar
# Processing Record 2 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | south river
# Processing Record 4 of Set 5 | garowe
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | amapa
# Processing Record 7 of Set 5 | mawlaik
# Processing Record 8 of Set 5 | quatre cocos
# Processing Record 9 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 5 | rust
# Processing Record 11 of Set 5 | iquique
# Processing Record 12 of Set 5 | biltine
# Processing Record 13 of Set 5 | parati
# Processing Record 14 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 5 | lebu
# Processing Record 17 of Set 5 | rabo de peixe
# Processing Record 18 of Set 5 | longyearbyen
# Processing Record 19 of Set 5 | yulara
# Processing Record 20 of Set 5 | ishigaki
# Processing Record 21 of Set 5 | inverell
# Processing Record 22 of Set 5 | avesta
# Processing Record 23 of Set 5 | wardha
# Processing Record 24 of Set 5 | filadelfia
# Processing Record 25 of Set 5 | datong
# Processing Record 26 of Set 5 | mayo
# Processing Record 27 of Set 5 | taltal
# Processing Record 28 of Set 5 | dryden
# Processing Record 29 of Set 5 | rabat
# Processing Record 30 of Set 5 | linxia
# Processing Record 31 of Set 5 | isangel
# Processing Record 32 of Set 5 | qui nhon
# Processing Record 33 of Set 5 | jerusalem
# Processing Record 34 of Set 5 | lodja
# Processing Record 35 of Set 5 | iqaluit
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 38 of Set 5 | vardo
# Processing Record 39 of Set 5 | castro
# Processing Record 40 of Set 5 | tura
# Processing Record 41 of Set 5 | sterling
# Processing Record 42 of Set 5 | bambous virieux
# Processing Record 43 of Set 5 | khani
# Processing Record 44 of Set 5 | dinghai
# Processing Record 45 of Set 5 | maceio
# Processing Record 46 of Set 5 | garmsar
# Processing Record 47 of Set 5 | ostrovnoy
# Processing Record 48 of Set 5 | mandalgovi
# Processing Record 49 of Set 5 | porto velho
# Processing Record 50 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 1 of Set 6 | north platte
# Processing Record 2 of Set 6 | butte
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | karatuzskoye
# Processing Record 5 of Set 6 | tsabong
# Processing Record 6 of Set 6 | jumla
# Processing Record 7 of Set 6 | bourail
# Processing Record 8 of Set 6 | belmonte
# Processing Record 9 of Set 6 | paita
# Processing Record 10 of Set 6 | chivilcoy
# Processing Record 11 of Set 6 | teya
# Processing Record 12 of Set 6 | yerbogachen
# Processing Record 13 of Set 6 | marsh harbour
# Processing Record 14 of Set 6 | preobrazheniye
# Processing Record 15 of Set 6 | ardrishaig
# Processing Record 16 of Set 6 | maniitsoq
# Processing Record 17 of Set 6 | mehran
# Processing Record 18 of Set 6 | lalmohan
# Processing Record 19 of Set 6 | stettler
# Processing Record 20 of Set 6 | dallas
# Processing Record 21 of Set 6 | yumen
# Processing Record 22 of Set 6 | soe
# Processing Record 23 of Set 6 | roald
# Processing Record 24 of Set 6 | puri
# Processing Record 25 of Set 6 | xinqing
# Processing Record 26 of Set 6 | mitsamiouli
# Processing Record 27 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 6 | pangnirtung
# Processing Record 29 of Set 6 | farafangana
# Processing Record 30 of Set 6 | sur
# Processing Record 31 of Set 6 | bengkulu
# Processing Record 32 of Set 6 | wasilla
# Processing Record 33 of Set 6 | nanakuli
# Processing Record 34 of Set 6 | moose factory
# Processing Record 35 of Set 6 | sorland
# Processing Record 36 of Set 6 | sokoni
# Processing Record 37 of Set 6 | bonthe
# Processing Record 38 of Set 6 | omboue
# Processing Record 39 of Set 6 | mirandela
# Processing Record 40 of Set 6 | khor
# Processing Record 41 of Set 6 | nouadhibou
# Processing Record 42 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 6 | adrar
# Processing Record 44 of Set 6 | talnakh
# Processing Record 45 of Set 6 | kungurtug
# Processing Record 46 of Set 6 | acapulco
# Processing Record 47 of Set 6 | izumo
# Processing Record 48 of Set 6 | lavrentiya
# Processing Record 49 of Set 6 | byron bay
# Processing Record 50 of Set 6 | pandan
# Processing Record 1 of Set 7 | maltahohe
# Processing Record 2 of Set 7 | wijnegem
# Processing Record 3 of Set 7 | bhawanipatna
# Processing Record 4 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 7 | camana
# Processing Record 6 of Set 7 | havre-saint-pierre
# Processing Record 7 of Set 7 | melito di porto salvo
# Processing Record 8 of Set 7 | ransang
# Processing Record 9 of Set 7 | amazar
# Processing Record 10 of Set 7 | bonfim
# Processing Record 11 of Set 7 | christchurch
# Processing Record 12 of Set 7 | zavidovici
# Processing Record 13 of Set 7 | codrington
# Processing Record 14 of Set 7 | hasaki
# Processing Record 15 of Set 7 | baculin
# Processing Record 16 of Set 7 | khatanga
# Processing Record 17 of Set 7 | sisimiut
# Processing Record 18 of Set 7 | gaur
# Processing Record 19 of Set 7 | victoria
# Processing Record 20 of Set 7 | katherine
# Processing Record 21 of Set 7 | san jeronimo
# Processing Record 22 of Set 7 | madingou
# Processing Record 23 of Set 7 | saint-georges
# Processing Record 24 of Set 7 | antofagasta
# Processing Record 25 of Set 7 | hobyo
# Processing Record 26 of Set 7 | egvekinot
# Processing Record 27 of Set 7 | alice springs
# Processing Record 28 of Set 7 | kvareli
# Processing Record 29 of Set 7 | asuncion nochixtlan
# Processing Record 30 of Set 7 | wanaka
# Processing Record 31 of Set 7 | mushie
# Processing Record 32 of Set 7 | severo-kurilsk
# Processing Record 33 of Set 7 | kibaya
# Processing Record 34 of Set 7 | tianpeng
# Processing Record 35 of Set 7 | manturovo
# Processing Record 36 of Set 7 | nogales
# Processing Record 37 of Set 7 | oussouye
# Processing Record 38 of Set 7 | siguiri
# Processing Record 39 of Set 7 | peterhead
# Processing Record 40 of Set 7 | parlakimidi
# Processing Record 41 of Set 7 | camocim
# Processing Record 42 of Set 7 | richards bay
# Processing Record 43 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 7 | artigas
# Processing Record 46 of Set 7 | lubango
# Processing Record 47 of Set 7 | guerrero negro
# Processing Record 48 of Set 7 | prado
# Processing Record 49 of Set 7 | harper
# Processing Record 50 of Set 7 | narsaq
# Processing Record 1 of Set 8 | faridpur
# Processing Record 2 of Set 8 | ekibastuz
# Processing Record 3 of Set 8 | pisco
# Processing Record 4 of Set 8 | baiyin
# Processing Record 5 of Set 8 | pleasanton
# Processing Record 6 of Set 8 | tabas
# Processing Record 7 of Set 8 | port macquarie
# Processing Record 8 of Set 8 | rocha
# Processing Record 9 of Set 8 | san patricio
# Processing Record 10 of Set 8 | souillac
# Processing Record 11 of Set 8 | rio grande
# Processing Record 12 of Set 8 | caravelas
# Processing Record 13 of Set 8 | valparaiso
# Processing Record 14 of Set 8 | kaduna
# Processing Record 15 of Set 8 | ngunguru
# Processing Record 16 of Set 8 | umm lajj
# Processing Record 17 of Set 8 | carutapera
# Processing Record 18 of Set 8 | rybnaya sloboda
# Processing Record 19 of Set 8 | mao
# Processing Record 20 of Set 8 | mount isa
# Processing Record 21 of Set 8 | urut
# Processing Record 22 of Set 8 | ilulissat
# Processing Record 23 of Set 8 | ulaanbaatar
# Processing Record 24 of Set 8 | tambilil
# Processing Record 25 of Set 8 | port augusta
# Processing Record 26 of Set 8 | kilindoni
# Processing Record 27 of Set 8 | santa rosa
# Processing Record 28 of Set 8 | kodinsk
# Processing Record 29 of Set 8 | burnie
# Processing Record 30 of Set 8 | ouadda
# Processing Record 31 of Set 8 | bubaque
# Processing Record 32 of Set 8 | saint-augustin
# Processing Record 33 of Set 8 | piacabucu
# Processing Record 34 of Set 8 | coquimbo
# Processing Record 35 of Set 8 | merauke
# Processing Record 36 of Set 8 | biri
# Processing Record 37 of Set 8 | prince rupert
# Processing Record 38 of Set 8 | hay river
# Processing Record 39 of Set 8 | novikovo
# Processing Record 40 of Set 8 | tucupita
# Processing Record 41 of Set 8 | saint anthony
# Processing Record 42 of Set 8 | aksarka
# Processing Record 43 of Set 8 | abu kamal
# Processing Record 44 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 8 | wiarton
# Processing Record 46 of Set 8 | suluq
# Processing Record 47 of Set 8 | itzehoe
# Processing Record 48 of Set 8 | bowling green
# Processing Record 49 of Set 8 | balabac
# Processing Record 50 of Set 8 | namatanai
# Processing Record 1 of Set 9 | rocky mountain house
# Processing Record 2 of Set 9 | constitucion
# Processing Record 3 of Set 9 | gornyye klyuchi
# Processing Record 4 of Set 9 | kiunga
# Processing Record 5 of Set 9 | linkoping
# Processing Record 6 of Set 9 | azar shahr
# City not found. Skipping...
# Processing Record 7 of Set 9 | zharkent
# Processing Record 8 of Set 9 | emilio carranza
# Processing Record 9 of Set 9 | tevaitoa
# Processing Record 10 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 9 | bundaberg
# Processing Record 12 of Set 9 | linares
# Processing Record 13 of Set 9 | ibra
# Processing Record 14 of Set 9 | luwuk
# Processing Record 15 of Set 9 | robeasca
# Processing Record 16 of Set 9 | whitianga
# Processing Record 17 of Set 9 | panalingaan
# Processing Record 18 of Set 9 | tessalit
# Processing Record 19 of Set 9 | otradnoye
# Processing Record 20 of Set 9 | nuuk
# Processing Record 21 of Set 9 | tambura
# Processing Record 22 of Set 9 | udachnyy
# Processing Record 23 of Set 9 | cherskiy
# Processing Record 24 of Set 9 | charlestown
# Processing Record 25 of Set 9 | oktyabrskiy
# Processing Record 26 of Set 9 | mlimba
# Processing Record 27 of Set 9 | dawlatabad
# Processing Record 28 of Set 9 | andenes
# Processing Record 29 of Set 9 | makung
# City not found. Skipping...
# Processing Record 30 of Set 9 | ulkan
# Processing Record 31 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 9 | roebourne
# Processing Record 33 of Set 9 | sayyan
# Processing Record 34 of Set 9 | sola
# Processing Record 35 of Set 9 | vao
# Processing Record 36 of Set 9 | tucurui
# Processing Record 37 of Set 9 | tiarei
# Processing Record 38 of Set 9 | strezhevoy
# Processing Record 39 of Set 9 | iguai
# Processing Record 40 of Set 9 | gornopravdinsk
# Processing Record 41 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 42 of Set 9 | flin flon
# Processing Record 43 of Set 9 | sovetskiy
# Processing Record 44 of Set 9 | kruisfontein
# Processing Record 45 of Set 9 | metro
# Processing Record 46 of Set 9 | kozakai
# City not found. Skipping...
# Processing Record 47 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 48 of Set 9 | noumea
# Processing Record 49 of Set 9 | karaton
# Processing Record 50 of Set 9 | itarema
# Processing Record 1 of Set 10 | bone
# Processing Record 2 of Set 10 | palasbari
# Processing Record 3 of Set 10 | cape canaveral
# Processing Record 4 of Set 10 | mattru
# Processing Record 5 of Set 10 | ilo
# Processing Record 6 of Set 10 | banikoara
# Processing Record 7 of Set 10 | vanimo
# Processing Record 8 of Set 10 | shingu
# Processing Record 9 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 10 | half moon bay
# Processing Record 11 of Set 10 | beringovskiy
# Processing Record 12 of Set 10 | santa cruz de la palma
# Processing Record 13 of Set 10 | lawrenceburg
# Processing Record 14 of Set 10 | sinnamary
# Processing Record 15 of Set 10 | watertown
# Processing Record 16 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 10 | heihe
# Processing Record 18 of Set 10 | kintampo
# Processing Record 19 of Set 10 | parana
# Processing Record 20 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 10 | mildura
# Processing Record 22 of Set 10 | santa luzia
# Processing Record 23 of Set 10 | vestmannaeyjar
# Processing Record 24 of Set 10 | kahului
# Processing Record 25 of Set 10 | tulum
# Processing Record 26 of Set 10 | namie
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | ajdabiya
# Processing Record 29 of Set 10 | betim
# Processing Record 30 of Set 10 | yuki
# Processing Record 31 of Set 10 | smithers
# Processing Record 32 of Set 10 | giyon
# Processing Record 33 of Set 10 | roros
# Processing Record 34 of Set 10 | geraldton
# Processing Record 35 of Set 10 | hualmay
# Processing Record 36 of Set 10 | fairbanks
# Processing Record 37 of Set 10 | ayorou
# Processing Record 38 of Set 10 | treinta y tres
# Processing Record 39 of Set 10 | puerto montt
# Processing Record 40 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 10 | nantucket
# Processing Record 42 of Set 10 | athmallik
# Processing Record 43 of Set 10 | terrasini
# Processing Record 44 of Set 10 | raton
# Processing Record 45 of Set 10 | kirovskiy
# Processing Record 46 of Set 10 | saint-joseph
# Processing Record 47 of Set 10 | touros
# Processing Record 48 of Set 10 | chapais
# Processing Record 49 of Set 10 | glen allen
# Processing Record 50 of Set 10 | shebunino
# Processing Record 1 of Set 11 | cabra
# Processing Record 2 of Set 11 | gobabis
# Processing Record 3 of Set 11 | weligama
# Processing Record 4 of Set 11 | chumikan
# Processing Record 5 of Set 11 | marawi
# Processing Record 6 of Set 11 | onega
# Processing Record 7 of Set 11 | newcastleton
# Processing Record 8 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 11 | norman wells
# Processing Record 10 of Set 11 | verkhoyansk
# Processing Record 11 of Set 11 | hershey
# Processing Record 12 of Set 11 | bandarbeyla
# Processing Record 13 of Set 11 | haines junction
# Processing Record 14 of Set 11 | kerema
# Processing Record 15 of Set 11 | santa cruz
# Processing Record 16 of Set 11 | sturgeon bay
# Processing Record 17 of Set 11 | college
# Processing Record 18 of Set 11 | pecsvarad
# Processing Record 19 of Set 11 | darnah
# Processing Record 20 of Set 11 | naryan-mar
# Processing Record 21 of Set 11 | usinsk
# Processing Record 22 of Set 11 | totness
# Processing Record 23 of Set 11 | kathmandu
# Processing Record 24 of Set 11 | santiago
# Processing Record 25 of Set 11 | dakar
# Processing Record 26 of Set 11 | paso de los toros
# Processing Record 27 of Set 11 | limon
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | vredendal
# Processing Record 30 of Set 11 | kyabe
# Processing Record 31 of Set 11 | douglas
# Processing Record 32 of Set 11 | valdivia
# Processing Record 33 of Set 11 | tabou
# Processing Record 34 of Set 11 | oxbow
# Processing Record 35 of Set 11 | bonavista
# Processing Record 36 of Set 11 | kaeo
# Processing Record 37 of Set 11 | kazachinskoye
# Processing Record 38 of Set 11 | dolores
# Processing Record 39 of Set 11 | matagami
# Processing Record 40 of Set 11 | makarov
# Processing Record 41 of Set 11 | de aar
# Processing Record 42 of Set 11 | asau
# Processing Record 43 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 11 | tooele
# Processing Record 45 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 11 | show low
# Processing Record 47 of Set 11 | beziers
# Processing Record 48 of Set 11 | kloulklubed
# Processing Record 49 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 11 | grindavik
# Processing Record 1 of Set 12 | berlevag
# Processing Record 2 of Set 12 | praia
# Processing Record 3 of Set 12 | ulladulla
# Processing Record 4 of Set 12 | kautokeino
# Processing Record 5 of Set 12 | kupang
# Processing Record 6 of Set 12 | norsup
# Processing Record 7 of Set 12 | leshukonskoye
# Processing Record 8 of Set 12 | nanortalik
# Processing Record 9 of Set 12 | rio gallegos
# Processing Record 10 of Set 12 | yarmouth
# Processing Record 11 of Set 12 | vuktyl
# Processing Record 12 of Set 12 | chimbote
# Processing Record 13 of Set 12 | tres arroyos
# Processing Record 14 of Set 12 | araceli
# Processing Record 15 of Set 12 | luderitz
# Processing Record 16 of Set 12 | cabo san lucas
# Processing Record 17 of Set 12 | makakilo city
# Processing Record 18 of Set 12 | mormugao
# Processing Record 19 of Set 12 | tyrma
# Processing Record 20 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 12 | dingle
# Processing Record 22 of Set 12 | san policarpo
# Processing Record 23 of Set 12 | luorong
# Processing Record 24 of Set 12 | uray
# Processing Record 25 of Set 12 | miami beach
# Processing Record 26 of Set 12 | waingapu
# Processing Record 27 of Set 12 | ushtobe
# Processing Record 28 of Set 12 | homer
# Processing Record 29 of Set 12 | alta floresta
# Processing Record 30 of Set 12 | nizhniy tsasuchey
# Processing Record 31 of Set 12 | port lincoln
# Processing Record 32 of Set 12 | paamiut
# Processing Record 33 of Set 12 | moindou
# Processing Record 34 of Set 12 | moussoro
# Processing Record 35 of Set 12 | rivers
# Processing Record 36 of Set 12 | gondanglegi
# Processing Record 37 of Set 12 | povenets
# Processing Record 38 of Set 12 | tahoua
# Processing Record 39 of Set 12 | los llanos de aridane
# Processing Record 40 of Set 12 | doctor arroyo
# Processing Record 41 of Set 12 | kartaly
# Processing Record 42 of Set 12 | grand gaube
# Processing Record 43 of Set 12 | rawson
# Processing Record 44 of Set 12 | general pico
# Processing Record 45 of Set 12 | port hardy
# Processing Record 46 of Set 12 | kikwit
# Processing Record 47 of Set 12 | umm kaddadah
# Processing Record 48 of Set 12 | zanzibar
# Processing Record 49 of Set 12 | dickinson
# Processing Record 50 of Set 12 | jaguaribe
# Processing Record 1 of Set 13 | krasnovishersk
# Processing Record 2 of Set 13 | russell
# Processing Record 3 of Set 13 | gouyave
# Processing Record 4 of Set 13 | mackay
# Processing Record 5 of Set 13 | juba
# Processing Record 6 of Set 13 | klaksvik
# Processing Record 7 of Set 13 | tahta
# Processing Record 8 of Set 13 | orneta
# Processing Record 9 of Set 13 | kampot
# Processing Record 10 of Set 13 | aripuana
# Processing Record 11 of Set 13 | netphen
# Processing Record 12 of Set 13 | daytona beach
# Processing Record 13 of Set 13 | queenstown
# Processing Record 14 of Set 13 | aleksandrov gay
# Processing Record 15 of Set 13 | marsa matruh
# Processing Record 16 of Set 13 | olivet
# Processing Record 17 of Set 13 | nhamunda
# Processing Record 18 of Set 13 | qostanay
# Processing Record 19 of Set 13 | iquitos
# Processing Record 20 of Set 13 | kota tinggi
# Processing Record 21 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 13 | coihaique
# Processing Record 23 of Set 13 | poum
# Processing Record 24 of Set 13 | glomfjord
# Processing Record 25 of Set 13 | teknaf
# Processing Record 26 of Set 13 | salalah
# Processing Record 27 of Set 13 | jingdezhen
# Processing Record 28 of Set 13 | turukhansk
# Processing Record 29 of Set 13 | panama city
# Processing Record 30 of Set 13 | forio
# Processing Record 31 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 32 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 33 of Set 13 | puerto colombia
# Processing Record 34 of Set 13 | benguela
# Processing Record 35 of Set 13 | mareeba
# Processing Record 36 of Set 13 | sehithwa
# Processing Record 37 of Set 13 | sibolga
# Processing Record 38 of Set 13 | voh
# Processing Record 39 of Set 13 | morant bay
# Processing Record 40 of Set 13 | saint-pierre
# Processing Record 41 of Set 13 | sinaloa
# Processing Record 42 of Set 13 | aberdeen
# Processing Record 43 of Set 13 | biak
# Processing Record 44 of Set 13 | temir
# Processing Record 45 of Set 13 | nhulunbuy
# Processing Record 46 of Set 13 | gejiu
# Processing Record 47 of Set 13 | clarence town
# Processing Record 48 of Set 13 | plettenberg bay
# Processing Record 49 of Set 13 | olafsvik
# Processing Record 50 of Set 13 | zhob
# Processing Record 1 of Set 14 | terney
# Processing Record 2 of Set 14 | minbu
# Processing Record 3 of Set 14 | ust-maya
# Processing Record 4 of Set 14 | voi
# Processing Record 5 of Set 14 | westport
# Processing Record 6 of Set 14 | margate
# Processing Record 7 of Set 14 | honiara
# Processing Record 8 of Set 14 | vostok
# Processing Record 9 of Set 14 | sobolevo
# Processing Record 10 of Set 14 | tilichiki
# Processing Record 11 of Set 14 | santa vitoria do palmar
# Processing Record 12 of Set 14 | kedrovyy
# Processing Record 13 of Set 14 | qabis
# City not found. Skipping...
# Processing Record 14 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 14 | port said
# Processing Record 16 of Set 14 | puerto leguizamo
# Processing Record 17 of Set 14 | tabat
# Processing Record 18 of Set 14 | pringsewu
# Processing Record 19 of Set 14 | boden
# Processing Record 20 of Set 14 | iranshahr
# Processing Record 21 of Set 14 | portland
# Processing Record 22 of Set 14 | okahandja
# Processing Record 23 of Set 14 | neuquen
# Processing Record 24 of Set 14 | obo
# Processing Record 25 of Set 14 | gao
# Processing Record 26 of Set 14 | maningrida
# Processing Record 27 of Set 14 | thaton
# Processing Record 28 of Set 14 | sergeyevka
# Processing Record 29 of Set 14 | lakhnau
# Processing Record 30 of Set 14 | pierre
# Processing Record 31 of Set 14 | levski
# Processing Record 32 of Set 14 | zeya
# Processing Record 33 of Set 14 | almaznyy
# Processing Record 34 of Set 14 | pemba
# Processing Record 35 of Set 14 | belis
# Processing Record 36 of Set 14 | ismailia
# Processing Record 37 of Set 14 | payakumbuh
# Processing Record 38 of Set 14 | lugovoy
# Processing Record 39 of Set 14 | athens
# Processing Record 40 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 14 | talcahuano
# Processing Record 42 of Set 14 | kieta
# Processing Record 43 of Set 14 | acarau
# Processing Record 44 of Set 14 | americus
# Processing Record 45 of Set 14 | tefe
# Processing Record 46 of Set 14 | lagoa
# Processing Record 47 of Set 14 | hernani
# Processing Record 48 of Set 14 | santa flavia
# Processing Record 49 of Set 14 | wajir
# Processing Record 50 of Set 14 | maraa
# Processing Record 1 of Set 15 | ko samui
# Processing Record 2 of Set 15 | sao raimundo nonato
# Processing Record 3 of Set 15 | bensonville
# Processing Record 4 of Set 15 | karratha
# Processing Record 5 of Set 15 | altay
# Processing Record 6 of Set 15 | port-gentil
# Processing Record 7 of Set 15 | norwood
# Processing Record 8 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 15 | fortuna
# Processing Record 10 of Set 15 | namibe
# Processing Record 11 of Set 15 | sioux lookout
# Processing Record 12 of Set 15 | saint-leu
# Processing Record 13 of Set 15 | kuching
# Processing Record 14 of Set 15 | bambanglipuro
# Processing Record 15 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 16 of Set 15 | cherrapunji
# Processing Record 17 of Set 15 | morden
# Processing Record 18 of Set 15 | kota kinabalu
# Processing Record 19 of Set 15 | alofi
# Processing Record 20 of Set 15 | boditi
# Processing Record 21 of Set 15 | pimenta bueno
# Processing Record 22 of Set 15 | trairi
# Processing Record 23 of Set 15 | shaunavon
# Processing Record 24 of Set 15 | vera cruz
# Processing Record 25 of Set 15 | bar
# Processing Record 26 of Set 15 | yenagoa
# Processing Record 27 of Set 15 | kovdor
# Processing Record 28 of Set 15 | garhi yasin
# Processing Record 29 of Set 15 | kuytun
# Processing Record 30 of Set 15 | lensk
# Processing Record 31 of Set 15 | banepa
# Processing Record 32 of Set 15 | rosetta
# Processing Record 33 of Set 15 | hailey
# Processing Record 34 of Set 15 | golyshmanovo
# Processing Record 35 of Set 15 | amantea
# Processing Record 36 of Set 15 | itaueira
# Processing Record 37 of Set 15 | brownsville
# Processing Record 38 of Set 15 | bonanza
# Processing Record 39 of Set 15 | san andres
# Processing Record 40 of Set 15 | yarada
# Processing Record 41 of Set 15 | nizwa
# Processing Record 42 of Set 15 | xam nua
# Processing Record 43 of Set 15 | amalapuram
# Processing Record 44 of Set 15 | nadym
# Processing Record 45 of Set 15 | kushchevskaya
# Processing Record 46 of Set 15 | manavalakurichi
# Processing Record 47 of Set 15 | nshamba
# Processing Record 48 of Set 15 | phan thiet
# Processing Record 49 of Set 15 | ahar
# Processing Record 50 of Set 15 | necochea
# Processing Record 1 of Set 16 | shanghai
# Processing Record 2 of Set 16 | yuci
# Processing Record 3 of Set 16 | dandong
# Processing Record 4 of Set 16 | otta
# Processing Record 5 of Set 16 | samoded
# Processing Record 6 of Set 16 | neiafu
# Processing Record 7 of Set 16 | atbasar
# Processing Record 8 of Set 16 | mecca
# Processing Record 9 of Set 16 | kenai
# Processing Record 10 of Set 16 | zhangzhou
# Processing Record 11 of Set 16 | paveh
# Processing Record 12 of Set 16 | meadow lake
# Processing Record 13 of Set 16 | sungaipenuh
# Processing Record 14 of Set 16 | kudahuvadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 711

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0       Albany  42.6001  -73.9662     70.36          few clouds        74
# 1  Novyy Urgal  51.0736  132.5642     26.60     overcast clouds        87
# 2  Yellowknife  62.4560 -114.3525     50.56       broken clouds        81
# 3  Clyde River  70.4692  -68.5914     21.43          few clouds        73
# 4  Provideniya  64.3833 -173.3000     36.57     overcast clouds        66
# 5    Busselton -33.6500  115.3333     47.44       broken clouds        79
# 6         Vila  42.0304   -8.1588     61.70    scattered clouds        59
# 7    Selikhino  50.3672  137.4996     32.14           clear sky        81
# 8        Pevek  69.7008  170.3133     26.40     overcast clouds        71
# 9   Karangasem  -8.4500  115.6167     76.48          light rain        91
#
#    Cloudiness  Wind Speed Country
# 0          22        1.01      US
# 1          91        0.51      RU
# 2          75        8.05      CA
# 3          20       13.80      CA
# 4          85        9.15      RU
# 5          81        3.76      AU
# 6          39        3.40      PT
# 7           7        4.65      RU
# 8         100       22.57      RU
# 9         100        6.20      ID

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
df = city_data_df.reindex(columns=new_column_order)

# Display sample data
df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.6001  -73.9662     70.36        74          22
# 1  Novyy Urgal      RU  51.0736  132.5642     26.60        87          91
# 2  Yellowknife      CA  62.4560 -114.3525     50.56        81          75
# 3  Clyde River      CA  70.4692  -68.5914     21.43        73          20
# 4  Provideniya      RU  64.3833 -173.3000     36.57        66          85
# 5    Busselton      AU -33.6500  115.3333     47.44        79          81
# 6         Vila      PT  42.0304   -8.1588     61.70        59          39
# 7    Selikhino      RU  50.3672  137.4996     32.14        81           7
# 8        Pevek      RU  69.7008  170.3133     26.40        71         100
# 9   Karangasem      ID  -8.4500  115.6167     76.48        91         100
#
#    Wind Speed Current Description
# 0        1.01          few clouds
# 1        0.51     overcast clouds
# 2        8.05       broken clouds
# 3       13.80          few clouds
# 4        9.15     overcast clouds
# 5        3.76       broken clouds
# 6        3.40    scattered clouds
# 7        4.65           clear sky
# 8       22.57     overcast clouds
# 9        6.20          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
